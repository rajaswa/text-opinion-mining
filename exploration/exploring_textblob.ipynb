# %%
from google.colab import drive
drive.mount('/gdrive')

with open('/gdrive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat '/gdrive/My Drive/foo.txt'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# Hello Google Drive!

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('brown')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# True

# %%
import pandas as pd
from textblob import TextBlob

# %%
df = pd.read_csv('/gdrive/My Drive/demonetization_tweets.csv', encoding = 'latin1')

# %%
docs = (df['text'])

# %%
text = TextBlob(docs[0])

# %%
text.tags
# Out:
# [('RT', 'NNP'),
#  ('@', 'NNP'),
#  ('rssurjewala', 'NN'),
#  ('Critical', 'JJ'),
#  ('question', 'NN'),
#  ('Was', 'NNP'),
#  ('PayTM', 'NNP'),
#  ('informed', 'VBD'),
#  ('about', 'RB'),
#  ('Demonetization', 'NNP'),
#  ('edict', 'NN'),
#  ('by', 'IN'),
#  ('PM', 'NNP'),
#  ('It', 'PRP'),
#  ("'s", 'VBZ'),
#  ('clearly', 'RB'),
#  ('fishy', 'JJ'),
#  ('and', 'CC'),
#  ('requires', 'VBZ'),
#  ('full', 'JJ'),
#  ('disclosure', 'NN'),
#  ('&', 'CC'),
#  ('amp', 'NN')]

# %%
text.noun_phrases
# Out:
# WordList(['rt', '@ rssurjewala', 'critical', 'was paytm', 'demonetization', 'pm', 'full disclosure'])

# %%
text.sentiment
# Out:
# Sentiment(polarity=0.15, subjectivity=0.5777777777777778)

# %%
count = 0
for doc in docs[:500]:
  text = TextBlob(doc)
  print(count)
  print(doc)
  print(text.noun_phrases)
  print()
  count += 1
# Out:
# 0
# RT @rssurjewala: Critical question: Was PayTM informed about #Demonetization edict by PM? It's clearly fishy and requires full disclosure &amp;
# ['rt', '@ rssurjewala', 'critical', 'was paytm', 'demonetization', 'pm', 'full disclosure']
#
# 1
# RT @Hemant_80: Did you vote on #Demonetization on Modi survey app?
# ['rt', 'hemant_80', 'demonetization', 'modi', 'survey app']
#
# 2
# RT @roshankar: Former FinSec, RBI Dy Governor, CBDT Chair + Harvard Professor lambaste #Demonetization.
#
# If not for Aam Aadmi, listen to th
# ['rt', '@ roshankar', 'finsec', 'rbi dy', 'cbdt chair', 'harvard professor', 'lambaste #', 'demonetization', 'aam aadmi']
#
# 3
# RT @ANI_news: Gurugram (Haryana): Post office employees provide cash exchange to patients in hospitals #demonetization https://t.co/uGMxUP9
# ['rt', 'ani_news', 'gurugram', 'haryana', 'post office employees', 'cash exchange', 'hospitals # demonetization https']
#
# 4
# RT @satishacharya: Reddy Wedding! @mail_today cartoon #demonetization #ReddyWedding https://t.co/u7gLNrq31F
# ['rt', '@ satishacharya', 'reddy wedding', '@ mail_today cartoon # demonetization #', 'reddywedding']
#
# 5
# @DerekScissors1: Indias #demonetization: #Blackmoney a symptom, not the disease https://t.co/HSl6Ihj0Qe via @ambazaarmag
# ['derekscissors1', 'india\x92s', '# demonetization', 'blackmoney', 'disease https', '@ ambazaarmag']
#
# 6
# RT @gauravcsawant: Rs 40 lakh looted from a bank in Kishtwar in J&amp;K. Third such incident since #demonetization. That's how terrorists have
# ['rt', '@ gauravcsawant', 'rs', 'kishtwar', 'k.', 'such incident', '# demonetization']
#
# 7
# RT @Joydeep_911: Calling all Nationalists to join...
# Walk for #CorruptionFreeIndia and spread the benefits of #Demonetization among the mas
# ['rt', 'joydeep_911', 'nationalists', 'walk', 'corruptionfreeindia', 'demonetization']
#
# 8
# RT @sumitbhati2002: Many opposition leaders are with @narendramodi on the #Demonetization
# And respect their decision,but support oppositio
# ['rt', '@ sumitbhati2002', 'opposition leaders', '@ narendramodi', 'demonetization', 'support oppositio']
#
# 9
# National reform now destroyed even the essence of sagan. Such instances urge giving #demonetization a second though https://t.co/eyySIREiUq
# ['national reform', 'such instances urge', '# demonetization']
#
# 10
# Many opposition leaders are with @narendramodi on the #Demonetization
# And respect their decision,but support opposition just b'coz of party
# ['opposition leaders', '@ narendramodi', 'demonetization', 'support opposition']
#
# 11
# RT @Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r
# ['rt', 'joydas', 'narendra modi app', 'pm', 'people support', 'demonetization', 'strategy https']
#
# 12
# @Jaggesh2 Bharat band on 28??<ed><U+00A0><U+00BD><ed><U+00B8><U+0082>Those who  are protesting #demonetization  are all different party leaders.
# ['jaggesh2 bharat', '> <', 'u+00a0', '> <', 'u+00bd', '> <', '> <', 'u+00b8', '> <', 'u+0082', '# demonetization', 'different party leaders']
#
# 13
# RT @Atheist_Krishna: The effect of #Demonetization !!
# . https://t.co/A8of7zh2f5
# ['rt', 'atheist_krishna', 'demonetization']
#
# 14
# RT @sona2905: When I explained #Demonetization to myself and tried to put it down in my words which are not laced with any heavy technical
# ['rt', '@ sona2905', 'demonetization']
#
# 15
# RT @Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards
# ['rt', 'dipankar_cpiml', 'modi', 'demonetization']
#
# 16
# RT @roshankar: Former FinSec, RBI Dy Governor, CBDT Chair + Harvard Professor lambaste #Demonetization.
#
# If not for Aam Aadmi, listen to th
# ['rt', '@ roshankar', 'finsec', 'rbi dy', 'cbdt chair', 'harvard professor', 'lambaste #', 'demonetization', 'aam aadmi']
#
# 17
# RT @Atheist_Krishna: BEFORE and AFTER Gandhi ji heard they are standing there against #Demonetization
# . https://t.co/9NheK63TPg
# ['rt', 'atheist_krishna', 'before', 'after gandhi', 'demonetization']
#
# 18
# RT @pGurus1: #Demonetization The co-operative banking sector in Kerala is as good as a tax haven. Is Kerala a Black Money HQ? https://t.co/
# ['rt', '@ pgurus1', 'demonetization', 'kerala', 'tax haven', 'kerala', 'black', 'hq']
#
# 19
# RT @roshankar: Former FinSec, RBI Dy Governor, CBDT Chair + Harvard Professor lambaste #Demonetization.
#
# If not for Aam Aadmi, listen to th
# ['rt', '@ roshankar', 'finsec', 'rbi dy', 'cbdt chair', 'harvard professor', 'lambaste #', 'demonetization', 'aam aadmi']
#
# 20
# RT @Hemant_80: Did you vote on #Demonetization on Modi survey app?
# ['rt', 'hemant_80', 'demonetization', 'modi', 'survey app']
#
# 21
# RT @roshankar: Former FinSec, RBI Dy Governor, CBDT Chair + Harvard Professor lambaste #Demonetization.
#
# If not for Aam Aadmi, listen to th
# ['rt', '@ roshankar', 'finsec', 'rbi dy', 'cbdt chair', 'harvard professor', 'lambaste #', 'demonetization', 'aam aadmi']
#
# 22
# RT @Atheist_Krishna: BEFORE and AFTER Gandhi ji heard they are standing there against #Demonetization
# . https://t.co/9NheK63TPg
# ['rt', 'atheist_krishna', 'before', 'after gandhi', 'demonetization']
#
# 23
# RT @MahikaInfra: @narendramodi
# @Swamy39
# The success of #Demonetization will depend on how swiftly govt replenish the currency
#
# Pls avoid Ba
# ['rt', 'mahikainfra', '@ narendramodi @', 'swamy39', 'demonetization', 'govt replenish', 'pls', 'ba']
#
# 24
# RT @Hemant_80: Did you vote on #Demonetization on Modi survey app?
# ['rt', 'hemant_80', 'demonetization', 'modi', 'survey app']
#
# 25
# RT @roshankar: Former FinSec, RBI Dy Governor, CBDT Chair + Harvard Professor lambaste #Demonetization.
#
# If not for Aam Aadmi, listen to th
# ['rt', '@ roshankar', 'finsec', 'rbi dy', 'cbdt chair', 'harvard professor', 'lambaste #', 'demonetization', 'aam aadmi']
#
# 26
# RT @kapil_kausik: #Doltiwal I mean #JaiChandKejriwal is "hurt" by #Demonetization as the same has rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired funds" No wo
# ['rt', '@ kapil_kausik', 'doltiwal', 'jaichandkejriwal', 'demonetization', 'useless', '> <', 'u+00a0', '> <', 'u+00bd', '> <', '> <', 'u+00b1', '> <', 'u+0089']
#
# 27
# RT @roshankar: Former FinSec, RBI Dy Governor, CBDT Chair + Harvard Professor lambaste #Demonetization.
#
# If not for Aam Aadmi, listen to th
# ['rt', '@ roshankar', 'finsec', 'rbi dy', 'cbdt chair', 'harvard professor', 'lambaste #', 'demonetization', 'aam aadmi']
#
# 28
# RT @kapil_kausik: #Doltiwal I mean #JaiChandKejriwal is "hurt" by #Demonetization as the same has rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired funds" No wo
# ['rt', '@ kapil_kausik', 'doltiwal', 'jaichandkejriwal', 'demonetization', 'useless', '> <', 'u+00a0', '> <', 'u+00bd', '> <', '> <', 'u+00b1', '> <', 'u+0089']
#
# 29
# RT @AAPVind: #Demonetization Is Disaster!  @naam_pk
# ['rt', 'aapvind', 'demonetization', 'disaster', '@ naam_pk']
#
# 30
# RT @Hemant_80: Did you vote on #Demonetization on Modi survey app?
# ['rt', 'hemant_80', 'demonetization', 'modi', 'survey app']
#
# 31
# RT @Gadgets360: After the #demonetization, searches about #NarendraModi's app are trending on app stores https://t.co/ZetKRqqClX
# ['rt', 'gadgets360', '# demonetization', 'narendramodi', "'s app", 'app stores https']
#
# 32
# RT @_avenu: Teacher: is there anybody who is absent today?
# (No response )
# Teacher says 100% attendance
# #Demonetization #App #survey
# @DonMu
# ['rt', '@ _avenu', 'teacher', 'teacher', '% attendance #', 'demonetization', 'app', '# survey @', 'donmu']
#
# 33
# RT @DrGPradhan: 8
#
# This tweet of @minimathur BIBI explains why she is having a prob with #demonetization ..In first part she says she can't
# ['rt', 'drgpradhan', '@ minimathur', 'bibi', '# demonetization ..in', "ca n't"]
#
# 34
# RT @mayankjain100: #demonetization is Communal and Black Money is Secular...
# ['rt', '@ mayankjain100', '# demonetization', 'communal', 'black', 'secular']
#
# 35
# LOL. #Demonetization Effect. https://t.co/aA5lfy9ALG
# ['lol', 'demonetization effect']
#
# 36
# RT @kapil_kausik: #Doltiwal I mean #JaiChandKejriwal is "hurt" by #Demonetization as the same has rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired funds" No wo
# ['rt', '@ kapil_kausik', 'doltiwal', 'jaichandkejriwal', 'demonetization', 'useless', '> <', 'u+00a0', '> <', 'u+00bd', '> <', '> <', 'u+00b1', '> <', 'u+0089']
#
# 37
# RT roshankar: Harvard's Larry Summers calls #Demonetization as poor policy with disproportionate negative impact o https://t.co/TPYJgXFBY8
# ['rt', 'harvard', 'larry summers', 'calls #', 'demonetization', 'poor policy', 'disproportionate negative impact o https']
#
# 38
# RT @Atheist_Krishna: BEFORE and AFTER Gandhi ji heard they are standing there against #Demonetization
# . https://t.co/9NheK63TPg
# ['rt', 'atheist_krishna', 'before', 'after gandhi', 'demonetization']
#
# 39
# @arunjaitley @narendramodi Lrnd frm a frnd-Banks r asking employees to comeback 2sales &amp; BAU Operations #Demonetization
# ['@ arunjaitley @ narendramodi', 'lrnd', 'frnd-banks r', 'comeback 2sales', 'bau operations', 'demonetization']
#
# 40
# RT @kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti
# ['rt', '@ kanimozhi', 'ts', 'pappu', 'demonetization', 'modi', 'bandwagon ti']
#
# 41
# RT @roshankar: Harvard's Larry Summers calls #Demonetization as poor policy with disproportionate negative impact on poor/trade.
#
# https://t
# ['rt', '@ roshankar', 'harvard', 'larry summers', 'calls #', 'demonetization', 'poor policy', 'disproportionate negative impact']
#
# 42
# RT @DrGPradhan: 8
#
# This tweet of @minimathur BIBI explains why she is having a prob with #demonetization ..In first part she says she can't
# ['rt', 'drgpradhan', '@ minimathur', 'bibi', '# demonetization ..in', "ca n't"]
#
# 43
# @dineshgrao you have 12.5 k followers yet you are not getting enough likes for your tweets against #demonetization. You need to introspect.
# ['@ dineshgrao', 'k followers', '# demonetization']
#
# 44
# #DeMonetization Effect : Visa, Master Card, Amex all Accepted :) https://t.co/ozDwcPKjaI
# ['demonetization effect', 'visa', 'card', 'amex']
#
# 45
# RT @DrGPradhan: 8
#
# This tweet of @minimathur BIBI explains why she is having a prob with #demonetization ..In first part she says she can't
# ['rt', 'drgpradhan', '@ minimathur', 'bibi', '# demonetization ..in', "ca n't"]
#
# 46
# RT @harshkkapoor: #DeMonetization survey results after 24 hours
# 5Lacs opinions
# Amazing response&amp; Commitment in fight against Blackmoney
# @na
# ['rt', '@ harshkkapoor', 'demonetization', 'survey results', 'hours 5lacs opinions', 'amazing', 'commitment', 'blackmoney', '@ na']
#
# 47
# RT @roshankar: Former FinSec, RBI Dy Governor, CBDT Chair + Harvard Professor lambaste #Demonetization.
#
# If not for Aam Aadmi, listen to th
# ['rt', '@ roshankar', 'finsec', 'rbi dy', 'cbdt chair', 'harvard professor', 'lambaste #', 'demonetization', 'aam aadmi']
#
# 48
# RT @rohanmlw: #demonetization eye opener video bt i doubt as few jurnos don't want2 hear +ve of @narendramodi @sardesairajdeep @ravishndtv
# ['rt', '@ rohanmlw', '# demonetization eye opener video bt i doubt', "n't want2", '@ narendramodi @ sardesairajdeep @ ravishndtv']
#
# 49
# RT @Punitspeaks: Survey result so far by @PMOIndia on #Demonetization. 5 lakh response in 24 hrs. 90% supports note ban. #MeraDeshBadalRaha
# ['rt', 'punitspeaks', 'survey', 'pmoindia', 'demonetization', 'lakh response', '% supports note ban', 'meradeshbadalraha']
#
# 50
# RT @nmleo1: Is #ModiSarkar 's #achedin campaign on #demonetization a #goebbelsian #masterstroke that turns blind eye to #GroundZero shocks?
# ['rt', '@ nmleo1', 'modisarkar', "'s # achedin campaign", '# demonetization', '# goebbelsian # masterstroke', 'blind eye', 'groundzero']
#
# 51
# RT @Punitspeaks: Survey result so far by @PMOIndia on #Demonetization. 5 lakh response in 24 hrs. 90% supports note ban. #MeraDeshBadalRaha
# ['rt', 'punitspeaks', 'survey', 'pmoindia', 'demonetization', 'lakh response', '% supports note ban', 'meradeshbadalraha']
#
# 52
# RT @DrGPradhan: 8
#
# This tweet of @minimathur BIBI explains why she is having a prob with #demonetization ..In first part she says she can't
# ['rt', 'drgpradhan', '@ minimathur', 'bibi', '# demonetization ..in', "ca n't"]
#
# 53
# #demonetization is Communal and Black Money is Secular...
# ['# demonetization', 'communal', 'black', 'secular']
#
# 54
# RT @kapil_kausik: #Doltiwal I mean #JaiChandKejriwal is "hurt" by #Demonetization as the same has rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired funds" No wo
# ['rt', '@ kapil_kausik', 'doltiwal', 'jaichandkejriwal', 'demonetization', 'useless', '> <', 'u+00a0', '> <', 'u+00bd', '> <', '> <', 'u+00b1', '> <', 'u+0089']
#
# 55
# RT @nmleo1: @MinhazMerchant #demonetization hardly affects tax dodgers &amp; #NETAS who excel in #CashlessCorruption &amp; have multiplied bad weal
# ['rt', '@ nmleo1', 'minhazmerchant', '# demonetization', 'affects tax dodgers', 'netas', 'cashlesscorruption', 'bad weal']
#
# 56
# RT @Atheist_Krishna: BEFORE and AFTER Gandhi ji heard they are standing there against #Demonetization
# . https://t.co/9NheK63TPg
# ['rt', 'atheist_krishna', 'before', 'after gandhi', 'demonetization']
#
# 57
# Section 144 issued by District Magistrate, #Indore prohibiting #socialmedia posts on #demonetization, Why??
# #citizen https://t.co/5Tn7aNBTsi
# ['magistrate', 'indore', '# socialmedia posts', '# demonetization', '# citizen https']
#
# 58
# RT @pGurus1: CPI-M opposes Co-op Banks in West Bengal but supports them in Kerala! Y Pawar U-turned on #Demonetization https://t.co/ThzaV7r
# ['rt', '@ pgurus1', 'cpi-m', 'co-op', 'bengal', 'kerala', 'y pawar u-turned', 'demonetization']
#
# 59
# RT roshankar: Harvard's Larry Summers calls #Demonetization as poor policy with disproportionate negative impact o https://t.co/vCWWjxu0wb
# ['rt', 'harvard', 'larry summers', 'calls #', 'demonetization', 'poor policy', 'disproportionate negative impact o https']
#
# 60
# RT @ZeeNewsSports: #Demonetization: @harbhajan_singh gives hilarious 'shagun' suggestion to those struggling with wedding season
#
# https://t
# ['rt', 'zeenewssports', 'demonetization', '@ harbhajan_singh', "hilarious 'shagun", 'wedding season https']
#
# 61
# RT @gauravcsawant: Rs 40 lakh looted from a bank in Kishtwar in J&amp;K. Third such incident since #demonetization. That's how terrorists have
# ['rt', '@ gauravcsawant', 'rs', 'kishtwar', 'k.', 'such incident', '# demonetization']
#
# 62
# RT @pGurus1: #Demonetization The time has come to put MUDRA into action, writes Prof. R Vaidyanathan - https://t.co/P6HkkDVa3b @upma23 @UnS
# ['rt', '@ pgurus1', 'demonetization', 'mudra', 'prof. r vaidyanathan', '//t.co/p6hkkdva3b @ upma23 @', 'uns']
#
# 63
# RT @pGurus1: #Demonetization move of Modi; Who is supporting it, who is opposing it and why? A complete coverage of all parties - https://t
# ['rt', '@ pgurus1', 'demonetization', 'modi', 'who', 'complete coverage']
#
# 64
# RT @Joydas: Question in Narendra Modi App where PM is taking feedback if people support his #DeMonetization strategy https://t.co/pYgK8Rmg7r
# ['rt', 'joydas', 'narendra modi app', 'pm', 'people support', 'demonetization', 'strategy https']
#
# 65
# RT @ModiBharosa: Huge support for PM @narendramodi s #demonetization Move Across the Nation
# 80-86% people back demonetization: C-voter su
# ['rt', 'modibharosa', 'huge', 'pm', '@ narendramodi \x92s # demonetization', 'move across', 'nation', '% people', 'c-voter']
#
# 66
# Effects of sluggish economy, negative IIP, #Demonetization ! Does the Great Leader even bother except continued dra https://t.co/DuvbMtEi1Y
# ['effects', 'sluggish economy', 'iip', 'demonetization', 'does', 'great leader', 'dra https']
#
# 67
# RT @kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti
# ['rt', '@ kanimozhi', 'ts', 'pappu', 'demonetization', 'modi', 'bandwagon ti']
#
# 68
# RT roshankar: Harvard's Larry Summers calls #Demonetization as poor policy with disproportionate negative impact o https://t.co/5J6jZXbY81
# ['rt', 'harvard', 'larry summers', 'calls #', 'demonetization', 'poor policy', 'disproportionate negative impact o https']
#
# 69
# RT @DrGPradhan: 8
#
# This tweet of @minimathur BIBI explains why she is having a prob with #demonetization ..In first part she says she can't
# ['rt', 'drgpradhan', '@ minimathur', 'bibi', '# demonetization ..in', "ca n't"]
#
# 70
# RT @bhaiyyajispeaks: Here @sardesairajdeep struggling for one answer against #Demonetization, He should have taken some Congress leader lik
# ['rt', '@ bhaiyyajispeaks', '@ sardesairajdeep', 'demonetization', 'congress', 'leader lik']
#
# 71
# #Demonetization and the Indian Economy An Interview by Doordarshan with Sri S.Gurumurthy https://t.co/LdeBCADAeR
# ['demonetization', 'economy', 'interview', 'doordarshan', 'sri s.gurumurthy']
#
# 72
# RT @Gadgets360: After the #demonetization, searches about #NarendraModi's app are trending on app stores https://t.co/ZetKRqqClX
# ['rt', 'gadgets360', '# demonetization', 'narendramodi', "'s app", 'app stores https']
#
# 73
# RT @roshankar: Former FinSec, RBI Dy Governor, CBDT Chair + Harvard Professor lambaste #Demonetization.
#
# If not for Aam Aadmi, listen to th
# ['rt', '@ roshankar', 'finsec', 'rbi dy', 'cbdt chair', 'harvard professor', 'lambaste #', 'demonetization', 'aam aadmi']
#
# 74
# RT @Punitspeaks: Survey result so far by @PMOIndia on #Demonetization. 5 lakh response in 24 hrs. 90% supports note ban. #MeraDeshBadalRaha
# ['rt', 'punitspeaks', 'survey', 'pmoindia', 'demonetization', 'lakh response', '% supports note ban', 'meradeshbadalraha']
#
# 75
# RT @NilimDutta: After much contemplation I have come to the conclusion that nothing explains Modi's #DeMonetization better than monumental
# ['rt', 'nilimdutta', 'modi', "'s #", 'demonetization']
#
# 76
# RT @Currency_crisis: What #demonetization indicates is loss of freedom
# Besides laws/constitution/court/cops 2 govern people
# govt is using m
# ['rt', 'currency_crisis', '# demonetization', 'people govt']
#
# 77
# RT @Hemant_80: Did you vote on #Demonetization on Modi survey app?
# ['rt', 'hemant_80', 'demonetization', 'modi', 'survey app']
#
# 78
# Ppl of India extending overwhelming supprt to @narendramodi Ji's crusade agnst black money.Survey @timesofindia https://t.co/Axqd8FOwpK
# ['ppl', 'india', '@ narendramodi', 'ji', "'s crusade agnst", 'black money.survey @ timesofindia https']
#
# 79
# RT @roshankar: Harvard's Larry Summers calls #Demonetization as poor policy with disproportionate negative impact on poor/trade.
#
# https://t
# ['rt', '@ roshankar', 'harvard', 'larry summers', 'calls #', 'demonetization', 'poor policy', 'disproportionate negative impact']
#
# 80
# RT @gauravcsawant: Rs 40 lakh looted from a bank in Kishtwar in J&amp;K. Third such incident since #demonetization. That's how terrorists have
# ['rt', '@ gauravcsawant', 'rs', 'kishtwar', 'k.', 'such incident', '# demonetization']
#
# 81
# RT @harshkkapoor: #DeMonetization survey results after 24 hours
# 5Lacs opinions
# Amazing response&amp; Commitment in fight against Blackmoney
# @na
# ['rt', '@ harshkkapoor', 'demonetization', 'survey results', 'hours 5lacs opinions', 'amazing', 'commitment', 'blackmoney', '@ na']
#
# 82
# People from rural areas are coming to Delhi just to withdraw cash.
#
# They have given up on govt. logistics.
#
# @ravishndtv #Demonetization
# ['rural areas', 'delhi', '@ ravishndtv #', 'demonetization']
#
# 83
# RT @rssurjewala: Critical question: Was PayTM informed about #Demonetization edict by PM? It's clearly fishy and requires full disclosure &amp;
# ['rt', '@ rssurjewala', 'critical', 'was paytm', 'demonetization', 'pm', 'full disclosure']
#
# 84
# RT @ZeeNewsSports: #Demonetization: @harbhajan_singh gives hilarious 'shagun' suggestion to those struggling with wedding season
#
# https://t
# ['rt', 'zeenewssports', 'demonetization', '@ harbhajan_singh', "hilarious 'shagun", 'wedding season https']
#
# 85
# RT @roshankar: Harvard's Larry Summers calls #Demonetization as poor policy with disproportionate negative impact on poor/trade.
#
# https://t
# ['rt', '@ roshankar', 'harvard', 'larry summers', 'calls #', 'demonetization', 'poor policy', 'disproportionate negative impact']
#
# 86
# RT roshankar: Harvard's Larry Summers calls #Demonetization as poor policy with disproportionate negative impact o https://t.co/vv9qtRqqSI
# ['rt', 'harvard', 'larry summers', 'calls #', 'demonetization', 'poor policy', 'disproportionate negative impact o https']
#
# 87
# RT @Joydeep_911: Calling all Nationalists to join...
# Walk for #CorruptionFreeIndia and spread the benefits of #Demonetization among the mas
# ['rt', 'joydeep_911', 'nationalists', 'walk', 'corruptionfreeindia', 'demonetization']
#
# 88
# RT @NilimDutta: After much contemplation I have come to the conclusion that nothing explains Modi's #DeMonetization better than monumental
# ['rt', 'nilimdutta', 'modi', "'s #", 'demonetization']
#
# 89
# RT @Atheist_Krishna: BEFORE and AFTER Gandhi ji heard they are standing there against #Demonetization
# . https://t.co/9NheK63TPg
# ['rt', 'atheist_krishna', 'before', 'after gandhi', 'demonetization']
#
# 90
# #demonetization 90 % of population is accepting it as country building measure, why these so called politicians opp https://t.co/f91j6tZjZ2
# ['# demonetization', 'country building measure', 'politicians opp https']
#
# 91
# RT @_avenu: Teacher: is there anybody who is absent today?
# (No response )
# Teacher says 100% attendance
# #Demonetization #App #survey
# @DonMu
# ['rt', '@ _avenu', 'teacher', 'teacher', '% attendance #', 'demonetization', 'app', '# survey @', 'donmu']
#
# 92
# 15 days after #demonetization, country is still suffering 4m acute shortage of currency notes.
# Big loss 2 economy
# Share market tumbling
# SOS
# ['# demonetization', 'acute shortage', 'big loss', 'share', 'sos']
#
# 93
# RT @Hemant_80: Did you vote on #Demonetization on Modi survey app?
# ['rt', 'hemant_80', 'demonetization', 'modi', 'survey app']
#
# 94
# RT @ashu3page: Man ends life over fund shortage ahead of daughters wedding in Gujarat. #Demonetization
# https://t.co/DGAI5cf05y
# https://t
# ['rt', '@ ashu3page', 'man ends life', 'fund shortage', 'daughter\x92s wedding', 'gujarat', 'demonetization', '//t.co/dgai5cf05y https']
#
# 95
# RT @ModiBharosa: Putting Nation over Party Politics #nitishkumar supports PM @narendramodi on #Demonetization https://t.co/UodwXdPMmG
# ['rt', 'modibharosa', 'putting nation', 'politics', '# nitishkumar supports', 'pm', '@ narendramodi', 'demonetization']
#
# 96
# RT @kapil_kausik: #Doltiwal I mean #JaiChandKejriwal is "hurt" by #Demonetization as the same has rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired funds" No wo
# ['rt', '@ kapil_kausik', 'doltiwal', 'jaichandkejriwal', 'demonetization', 'useless', '> <', 'u+00a0', '> <', 'u+00bd', '> <', '> <', 'u+00b1', '> <', 'u+0089']
#
# 97
# RT @Joydeep_911: Calling all Nationalists to join...
# Walk for #CorruptionFreeIndia and spread the benefits of #Demonetization among the mas
# ['rt', 'joydeep_911', 'nationalists', 'walk', 'corruptionfreeindia', 'demonetization']
#
# 98
# RT @TheOfficialSBI: As of today, 33000 thousand ATMs are functioning. - SBI Chairman, Smt. Arundhati Bhattacharya. #Demonetization
# ['rt', 'theofficialsbi', 'atms', 'sbi', 'smt', 'arundhati bhattacharya', 'demonetization']
#
# 99
# RT @ashu3page: A man shaved his head at Jantar-Mantar in protest against #Demonetization  on 13th day of the move. https://t.co/IeXuia3J0X
# ['rt', '@ ashu3page', 'jantar-mantar', 'demonetization']
#
# 100
# Very unfortunate... India slips due to #demonetization
# @BJP4India @PMOIndia @RanaAyyub @TruthOfGujarat @AnupamPkher
# https://t.co/6QhcGyBpKw
# ['unfortunate ...', 'india', '# demonetization @', 'bjp4india', 'pmoindia', 'ranaayyub', 'truthofgujarat', 'anupampkher']
#
# 101
# What #demonetization indicates is loss of freedom
# Besides laws/constitution/court/cops 2 govern people
# govt is using money 2 control people
# ['# demonetization', 'people govt', 'control people']
#
# 102
# RT @roshankar: Harvard's Larry Summers calls #Demonetization as poor policy with disproportionate negative impact on poor/trade.
#
# https://t
# ['rt', '@ roshankar', 'harvard', 'larry summers', 'calls #', 'demonetization', 'poor policy', 'disproportionate negative impact']
#
# 103
# RT @pGurus1: #Demonetization The time has come to put MUDRA into action, writes Prof. R Vaidyanathan - https://t.co/P6HkkDVa3b @upma23 @UnS
# ['rt', '@ pgurus1', 'demonetization', 'mudra', 'prof. r vaidyanathan', '//t.co/p6hkkdva3b @ upma23 @', 'uns']
#
# 104
# RT @sitaramlamba: Cooperative banks shut down, sowing season completely disrupted, agri markets &amp; Farmers badly affected #demonetization
# ['rt', '@ sitaramlamba', 'cooperative', 'banks shut', 'agri markets', '# demonetization']
#
# 105
# RT @Punitspeaks: Survey result so far by @PMOIndia on #Demonetization. 5 lakh response in 24 hrs. 90% supports note ban. #MeraDeshBadalRaha
# ['rt', 'punitspeaks', 'survey', 'pmoindia', 'demonetization', 'lakh response', '% supports note ban', 'meradeshbadalraha']
#
# 106
# RT @embracetheart: Delete! Pathetic PM who conducts false poll and self praises himself. #demonetization #BogusPoll #ModiScaredOfParliament
# ['rt', '@ embracetheart', 'delete', 'pathetic pm', 'false poll', 'self praises', '# demonetization #', 'boguspoll', 'modiscaredofparliament']
#
# 107
# RT @Atheist_Krishna: BEFORE and AFTER Gandhi ji heard they are standing there against #Demonetization
# . https://t.co/9NheK63TPg
# ['rt', 'atheist_krishna', 'before', 'after gandhi', 'demonetization']
#
# 108
# RT @ZeeNewsSports: #Demonetization: @harbhajan_singh gives hilarious 'shagun' suggestion to those struggling with wedding season
#
# https://t
# ['rt', 'zeenewssports', 'demonetization', '@ harbhajan_singh', "hilarious 'shagun", 'wedding season https']
#
# 109
# RT @_avenu: Teacher: is there anybody who is absent today?
# (No response )
# Teacher says 100% attendance
# #Demonetization #App #survey
# @DonMu
# ['rt', '@ _avenu', 'teacher', 'teacher', '% attendance #', 'demonetization', 'app', '# survey @', 'donmu']
#
# 110
# #Demonetization
# https://t.co/0kq8BsJ1iS
# When PM is in, opposition is out of parliament.
# ['demonetization', 'pm']
#
# 111
# RT @kapil_kausik: #Doltiwal I mean #JaiChandKejriwal is "hurt" by #Demonetization as the same has rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired funds" No wo
# ['rt', '@ kapil_kausik', 'doltiwal', 'jaichandkejriwal', 'demonetization', 'useless', '> <', 'u+00a0', '> <', 'u+00bd', '> <', '> <', 'u+00b1', '> <', 'u+0089']
#
# 112
# RT @CMOMaharashtra: Watch what @sonunigam thinks about #demonetization .. https://t.co/vXt09c64zY
# ['rt', 'cmomaharashtra', 'watch', '@ sonunigam', '# demonetization .. https']
#
# 113
# RT @ShashiTharoor: . @anandkamal Frankly i don't understand why @narendramodi doesn't address Parlmnt on #Demonetization. It's his duty&amp;wil
# ['rt', 'shashitharoor', '@ anandkamal', 'frankly', '@ narendramodi', "n't address", 'parlmnt', 'demonetization']
#
# 114
# RT @_avenu: Teacher: is there anybody who is absent today?
# (No response )
# Teacher says 100% attendance
# #Demonetization #App #survey
# @DonMu
# ['rt', '@ _avenu', 'teacher', 'teacher', '% attendance #', 'demonetization', 'app', '# survey @', 'donmu']
#
# 115
# RT @_avenu: Teacher: is there anybody who is absent today?
# (No response )
# Teacher says 100% attendance
# #Demonetization #App #survey
# @DonMu
# ['rt', '@ _avenu', 'teacher', 'teacher', '% attendance #', 'demonetization', 'app', '# survey @', 'donmu']
#
# 116
# RT @kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti
# ['rt', '@ kanimozhi', 'ts', 'pappu', 'demonetization', 'modi', 'bandwagon ti']
#
# 117
# RT @DrGPradhan: 8
#
# This tweet of @minimathur BIBI explains why she is having a prob with #demonetization ..In first part she says she can't
# ['rt', 'drgpradhan', '@ minimathur', 'bibi', '# demonetization ..in', "ca n't"]
#
# 118
# RT @kapil_kausik: #Doltiwal I mean #JaiChandKejriwal is "hurt" by #Demonetization as the same has rendered USELESS <ed><U+00A0><U+00BD><ed><U+00B1><U+0089> "acquired funds" No wo
# ['rt', '@ kapil_kausik', 'doltiwal', 'jaichandkejriwal', 'demonetization', 'useless', '> <', 'u+00a0', '> <', 'u+00bd', '> <', '> <', 'u+00b1', '> <', 'u+0089']
#
# 119
# RT @_avenu: Teacher: is there anybody who is absent today?
# (No response )
# Teacher says 100% attendance
# #Demonetization #App #survey
# @DonMu
# ['rt', '@ _avenu', 'teacher', 'teacher', '% attendance #', 'demonetization', 'app', '# survey @', 'donmu']
#
# 120
# RT @Hemant_80: Did you vote on #Demonetization on Modi survey app?
# ['rt', 'hemant_80', 'demonetization', 'modi', 'survey app']
#
# 121
# RT @ZeeNewsSports: #Demonetization: @harbhajan_singh gives hilarious 'shagun' suggestion to those struggling with wedding season
#
# https://t
# ['rt', 'zeenewssports', 'demonetization', '@ harbhajan_singh', "hilarious 'shagun", 'wedding season https']
#
# 122
# RT @pGurus1: #Demonetization move of Modi; Who is supporting it, who is opposing it and why? A complete coverage of all parties - https://t
# ['rt', '@ pgurus1', 'demonetization', 'modi', 'who', 'complete coverage']
#
# 123
# RT @DrGPradhan: 8
#
# This tweet of @minimathur BIBI explains why she is having a prob with #demonetization ..In first part she says she can't
# ['rt', 'drgpradhan', '@ minimathur', 'bibi', '# demonetization ..in', "ca n't"]
#
# 124
# Aam aadmi punished for sins of #blackmoney hoarders. SBI slashes  deposit rates by 1.9% #Demonetization #netascashin https://t.co/rqjsdiGvcG
# ['aam', '# blackmoney hoarders', 'sbi', 'slashes deposit rates', '% #', 'demonetization', '# netascashin https']
#
# 125
# Teacher: is there anybody who is absent today?
# (No response )
# Teacher says 100% attendance
# #Demonetization #App #survey
# @DonMufflerMan <ed><U+00A0><U+00BD><ed><U+00B8><U+0082><ed><U+00A0><U+00BD><ed><U+00B8><U+0080><ed><U+00A0><U+00BD><ed><U+00B8><U+00A0><ed><U+00A0><U+00BD><ed><U+00B8><U+00AE>
# ['teacher', 'teacher', '% attendance #', 'demonetization', 'app', '# survey @', 'donmufflerman', '> <', 'u+00a0', '> <', 'u+00bd', '> <', '> <', 'u+00b8', '> <', 'u+0082', '> <', '> <', 'u+00a0', '> <', 'u+00bd', '> <', '> <', 'u+00b8', '> <', 'u+0080', '> <', '> <', 'u+00a0', '> <', 'u+00bd', '> <', '> <', 'u+00b8', '> <', 'u+00a0', '> <', '> <', 'u+00a0', '> <', 'u+00bd', '> <', '> <', 'u+00b8', '> <', 'u+00ae']
#
# 126
# RT @Punitspeaks: Survey result so far by @PMOIndia on #Demonetization. 5 lakh response in 24 hrs. 90% supports note ban. #MeraDeshBadalRaha
# ['rt', 'punitspeaks', 'survey', 'pmoindia', 'demonetization', 'lakh response', '% supports note ban', 'meradeshbadalraha']
#
# 127
# RT @ANI_news: The queues are not getting longer but are getting shorter day by day: Chanda Kochar,ICIC MD and CEO #demonetization https://t
# ['rt', 'ani_news', 'shorter day', 'chanda kochar', 'icic md', 'ceo', '# demonetization https']
#
# 128
# RT @DrGPradhan: 8
#
# This tweet of @minimathur BIBI explains why she is having a prob with #demonetization ..In first part she says she can't
# ['rt', 'drgpradhan', '@ minimathur', 'bibi', '# demonetization ..in', "ca n't"]
#
# 129
# RT @karnataka_ioc: @indianoilcl giving cash through Mini ATMs to people in Hinterland. #IndiaKaDil. Helping rural people in #Demonetization
# ['rt', '@ karnataka_ioc', '@ indianoilcl', 'mini atms', 'hinterland', 'indiakadil', 'rural people', 'demonetization']
#
# 130
# RT @Hemant_80: Did you vote on #Demonetization on Modi survey app?
# ['rt', 'hemant_80', 'demonetization', 'modi', 'survey app']
#
# 131
# RT @PIB_India: Watch briefing on #Demonetization by DEA Secy @DasShaktikanta this morning here:
# https://t.co/TDj2A6uO5u
# ['rt', 'pib_india', 'watch', 'demonetization', 'dea secy', 'dasshaktikanta']
#
# 132
# @DeshhBhakt seems deskbhakt was in hibernation mode when GPS enabled 2000 rs was launched by #Modo 4 #demonetization <ed><U+00A0><U+00BD><ed><U+00B8><U+0082><ed><U+00A0><U+00BD><ed><U+00B8><U+0082><ed><U+00A0><U+00BD><ed><U+00B8><U+0082>@MonaAmbegaonkar
# ['deshhbhakt', 'hibernation mode', 'gps', 'modo', '# demonetization <', '> <', 'u+00a0', '> <', 'u+00bd', '> <', '> <', 'u+00b8', '> <', 'u+0082', '> <', '> <', 'u+00a0', '> <', 'u+00bd', '> <', '> <', 'u+00b8', '> <', 'u+0082', '> <', '> <', 'u+00a0', '> <', 'u+00bd', '> <', '> <', 'u+00b8', '> <', 'u+0082', '> @', 'monaambegaonkar']
#
# 133
# RT @roshankar: Harvard's Larry Summers calls #Demonetization as poor policy with disproportionate negative impact on poor/trade.
#
# https://t
# ['rt', '@ roshankar', 'harvard', 'larry summers', 'calls #', 'demonetization', 'poor policy', 'disproportionate negative impact']
#
# 134
# RT @Hemant_80: Did you vote on #Demonetization on Modi survey app?
# ['rt', 'hemant_80', 'demonetization', 'modi', 'survey app']
#
# 135
# RT @dhrumilpatel: Looks Ambit Capital, literally Choked with #demonetization, come-on U can't lower d GDP nos by huge margin.
# Perhaps, they
# ['rt', '@ dhrumilpatel', 'looks ambit capital', 'choked', '# demonetization', "ca n't", 'gdp']
#
# 136
# RT @ZeeNewsSports: #Demonetization: @harbhajan_singh gives hilarious 'shagun' suggestion to those struggling with wedding season
#
# https://t
# ['rt', 'zeenewssports', 'demonetization', '@ harbhajan_singh', "hilarious 'shagun", 'wedding season https']
#
# 137
# RT @bi_india: .@airtelindia takes a bite of the governemnt big #demonetization pie, becomes first #paymentbank to go live
#
# https://t.co/gZv
# ['rt', '@ bi_india', '@ airtelindia', 'big # demonetization pie', '# paymentbank']
#
# 138
# RT @harshkkapoor: #DeMonetization survey results after 24 hours
# 5Lacs opinions
# Amazing response&amp; Commitment in fight against Blackmoney
# @na
# ['rt', '@ harshkkapoor', 'demonetization', 'survey results', 'hours 5lacs opinions', 'amazing', 'commitment', 'blackmoney', '@ na']
#
# 139
# RT @ModiBharosa: Huge support for PM @narendramodi s #demonetization Move Across the Nation
# 80-86% people back demonetization: C-voter su
# ['rt', 'modibharosa', 'huge', 'pm', '@ narendramodi \x92s # demonetization', 'move across', 'nation', '% people', 'c-voter']
#
# 140
# RT @roshankar: Former FinSec, RBI Dy Governor, CBDT Chair + Harvard Professor lambaste #Demonetization.
#
# If not for Aam Aadmi, listen to th
# ['rt', '@ roshankar', 'finsec', 'rbi dy', 'cbdt chair', 'harvard professor', 'lambaste #', 'demonetization', 'aam aadmi']
#
# 141
# RT @roshankar: Harvard's Larry Summers calls #Demonetization as poor policy with disproportionate negative impact on poor/trade.
#
# https://t
# ['rt', '@ roshankar', 'harvard', 'larry summers', 'calls #', 'demonetization', 'poor policy', 'disproportionate negative impact']
#
# 142
# The opposition is getting troubled because all their #BlackMoney have become just a piece of paper due to #demonetization #<U+092C><U+0940><U+092E><U+093E><U+0930>_<U+0935><U+093F><U+092A><U+0915><U+094D><U+0937>
# ['blackmoney', '# demonetization # <', 'u+092c', '> <', 'u+0940', '> <', 'u+092e', '> <', 'u+093e', '> <', 'u+0930', '> _ <', 'u+0935', '> <', 'u+093f', '> <', 'u+092a', '> <', 'u+0915', '> <', 'u+094d', '> <', 'u+0937']
#
# 143
# RT @roshankar: Harvard's Larry Summers calls #Demonetization as poor policy with disproportionate negative impact on poor/trade.
#
# https://t
# ['rt', '@ roshankar', 'harvard', 'larry summers', 'calls #', 'demonetization', 'poor policy', 'disproportionate negative impact']
#
# 144
# RT @roshankar: Harvard's Larry Summers calls #Demonetization as poor policy with disproportionate negative impact on poor/trade.
#
# https://t
# ['rt', '@ roshankar', 'harvard', 'larry summers', 'calls #', 'demonetization', 'poor policy', 'disproportionate negative impact']
#
# 145
# RT @roshankar: Harvard's Larry Summers calls #Demonetization as poor policy with disproportionate negative impact on poor/trade.
#
# https://t
# ['rt', '@ roshankar', 'harvard', 'larry summers', 'calls #', 'demonetization', 'poor policy', 'disproportionate negative impact']
#
# 146
# RT @ZeeNewsSports: #Demonetization: @harbhajan_singh gives hilarious 'shagun' suggestion to those struggling with wedding season
#
# https://t
# ['rt', 'zeenewssports', 'demonetization', '@ harbhajan_singh', "hilarious 'shagun", 'wedding season https']
#
# 147
# @sritara @GabbbarSingh @sidin
# Please read alternative side of story also on #Demonetization &amp; support to PM Modi
# https://t.co/SLJoymBy1m
# ['@ sritara @', 'gabbbarsingh', '@ sidin', 'please', 'alternative side', 'demonetization', 'pm modi']
#
# 148
# The effect of #DeMonetization has already shared by @narendramodi  #Action are more important than words https://t.co/TbCC8S5ETc
# ['demonetization', '@ narendramodi # action', 'words https']
#
# 149
# RT @ShashiTharoor: Joined the line of Opposition MPs demonstrating solidarity on #demonetization &amp;demanding that @PMOIndia address Parliame
# ['rt', 'shashitharoor', 'joined', 'mps', '# demonetization', 'pmoindia', 'parliame']
#
# 150
# RT @ZeeNewsSports: #Demonetization: @harbhajan_singh gives hilarious 'shagun' suggestion to those struggling with wedding season
#
# https://t
# ['rt', 'zeenewssports', 'demonetization', '@ harbhajan_singh', "hilarious 'shagun", 'wedding season https']
#
# 151
# After much contemplation I have come to the conclusion that nothing explains Modi's #DeMonetization better than monumental stupidity.
# ['modi', "'s #", 'demonetization', 'monumental stupidity']
#
# 152
# RT @gauravcsawant: Rs 40 lakh looted from a bank in Kishtwar in J&amp;K. Third such incident since #demonetization. That's how terrorists have
# ['rt', '@ gauravcsawant', 'rs', 'kishtwar', 'k.', 'such incident', '# demonetization']
#
# 153
# RT @roshankar: Former FinSec, RBI Dy Governor, CBDT Chair + Harvard Professor lambaste #Demonetization.
#
# If not for Aam Aadmi, listen to th
# ['rt', '@ roshankar', 'finsec', 'rbi dy', 'cbdt chair', 'harvard professor', 'lambaste #', 'demonetization', 'aam aadmi']
#
# 154
# RT @ZeeNewsSports: #Demonetization: @harbhajan_singh gives hilarious 'shagun' suggestion to those struggling with wedding season
#
# https://t
# ['rt', 'zeenewssports', 'demonetization', '@ harbhajan_singh', "hilarious 'shagun", 'wedding season https']
#
# 155
# RT @YSRCParty: Days before #Demonetization announcement, @ncbn sold his Heritage shares,clearly evident that he had prior knowledge of the
# ['rt', 'ysrcparty', 'demonetization', '@ ncbn', 'heritage shares']
#
# 156
# RT @TheOfficialSBI: In view of  current situation, RTGS time  has been extended upto 6:30 PM till 24th November, 2016. #Demonetization http
# ['rt', 'theofficialsbi', 'current situation', 'rtgs', 'pm', 'november', 'demonetization']
#
# 157
# RT ZeeNewsSports: #Demonetization: harbhajan_singh gives hilarious 'shagun' suggestion to those struggling with we https://t.co/TaCfmKF3Cs
# ['rt zeenewssports', 'demonetization', "hilarious 'shagun"]
#
# 158
# RT @DrGPradhan: 8
#
# This tweet of @minimathur BIBI explains why she is having a prob with #demonetization ..In first part she says she can't
# ['rt', 'drgpradhan', '@ minimathur', 'bibi', '# demonetization ..in', "ca n't"]
#
# 159
# RT @DrGPradhan: 8
#
# This tweet of @minimathur BIBI explains why she is having a prob with #demonetization ..In first part she says she can't
# ['rt', 'drgpradhan', '@ minimathur', 'bibi', '# demonetization ..in', "ca n't"]
#
# 160
# RT @Punitspeaks: Survey result so far by @PMOIndia on #Demonetization. 5 lakh response in 24 hrs. 90% supports note ban. #MeraDeshBadalRaha
# ['rt', 'punitspeaks', 'survey', 'pmoindia', 'demonetization', 'lakh response', '% supports note ban', 'meradeshbadalraha']
#
# 161
# RT @ZeeNewsSports: #Demonetization: @harbhajan_singh gives hilarious 'shagun' suggestion to those struggling with wedding season
#
# https://t
# ['rt', 'zeenewssports', 'demonetization', '@ harbhajan_singh', "hilarious 'shagun", 'wedding season https']
#
# 162
# RT @YSRCParty: Days before #Demonetization announcement, @ncbn sold his Heritage shares,clearly evident that he had prior knowledge of the
# ['rt', 'ysrcparty', 'demonetization', '@ ncbn', 'heritage shares']
#
# 163
# RT @ZeeNewsSports: #Demonetization: @harbhajan_singh gives hilarious 'shagun' suggestion to those struggling with wedding season
#
# https://t
# ['rt', 'zeenewssports', 'demonetization', '@ harbhajan_singh', "hilarious 'shagun", 'wedding season https']
#
# 164
# RT @roshankar: Former FinSec, RBI Dy Governor, CBDT Chair + Harvard Professor lambaste #Demonetization.
#
# If not for Aam Aadmi, listen to th
# ['rt', '@ roshankar', 'finsec', 'rbi dy', 'cbdt chair', 'harvard professor', 'lambaste #', 'demonetization', 'aam aadmi']
#
# 165
# RT @Atheist_Krishna: BEFORE and AFTER Gandhi ji heard they are standing there against #Demonetization
# . https://t.co/9NheK63TPg
# ['rt', 'atheist_krishna', 'before', 'after gandhi', 'demonetization']
#
# 166
# RT @ZeeNewsSports: #Demonetization: @harbhajan_singh gives hilarious 'shagun' suggestion to those struggling with wedding season
#
# https://t
# ['rt', 'zeenewssports', 'demonetization', '@ harbhajan_singh', "hilarious 'shagun", 'wedding season https']
#
# 167
# Former FinSec, RBI Dy Governor, CBDT Chair + Harvard Professor lambaste #Demonetization.
#
# If not for Aam Aadmi, listen to them no PM Modi?
# ['finsec', 'rbi dy', 'cbdt chair', 'harvard professor', 'lambaste #', 'demonetization', 'aam aadmi', 'pm modi']
#
# 168
# RT ZeeNewsSports: #Demonetization: harbhajan_singh gives hilarious 'shagun' suggestion to those struggling with we https://t.co/oJrbCBYmH9
# ['rt zeenewssports', 'demonetization', "hilarious 'shagun"]
#
# 169
# RT @Punitspeaks: Survey result so far by @PMOIndia on #Demonetization. 5 lakh response in 24 hrs. 90% supports note ban. #MeraDeshBadalRaha
# ['rt', 'punitspeaks', 'survey', 'pmoindia', 'demonetization', 'lakh response', '% supports note ban', 'meradeshbadalraha']
#
# 170
# RT @Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards
# ['rt', 'dipankar_cpiml', 'modi', 'demonetization']
#
# 171
# RT @_Hinduism_: How come those people crying for line in banks are not crying for line ups here in......
#
# #demonetization https://t.co/ixY1
# ['rt', '@ _hinduism_', 'line ups', '... ... # demonetization https']
#
# 172
# RT @ZeeNewsSports: #Demonetization: @harbhajan_singh gives hilarious 'shagun' suggestion to those struggling with wedding season
#
# https://t
# ['rt', 'zeenewssports', 'demonetization', '@ harbhajan_singh', "hilarious 'shagun", 'wedding season https']
#
# 173
# RT @DrGPradhan: 8
#
# This tweet of @minimathur BIBI explains why she is having a prob with #demonetization ..In first part she says she can't
# ['rt', 'drgpradhan', '@ minimathur', 'bibi', '# demonetization ..in', "ca n't"]
#
# 174
# RT @Atheist_Krishna: BEFORE and AFTER Gandhi ji heard they are standing there against #Demonetization
# . https://t.co/9NheK63TPg
# ['rt', 'atheist_krishna', 'before', 'after gandhi', 'demonetization']
#
# 175
# RT @Atheist_Krishna: BEFORE and AFTER Gandhi ji heard they are standing there against #Demonetization
# . https://t.co/9NheK63TPg
# ['rt', 'atheist_krishna', 'before', 'after gandhi', 'demonetization']
#
# 176
# RT @ZeeNewsSports: #Demonetization: @harbhajan_singh gives hilarious 'shagun' suggestion to those struggling with wedding season
#
# https://t
# ['rt', 'zeenewssports', 'demonetization', '@ harbhajan_singh', "hilarious 'shagun", 'wedding season https']
#
# 177
# RT @gauravcsawant: Rs 40 lakh looted from a bank in Kishtwar in J&amp;K. Third such incident since #demonetization. That's how terrorists have
# ['rt', '@ gauravcsawant', 'rs', 'kishtwar', 'k.', 'such incident', '# demonetization']
#
# 178
# #Demonetization: @harbhajan_singh gives hilarious 'shagun' suggestion to those struggling with wedding season https://t.co/6QNe6KGqaO
# ['demonetization', '@ harbhajan_singh', "hilarious 'shagun", 'wedding season https']
#
# 179
# RT @ashu3page: A man shaved his head at Jantar-Mantar in protest against #Demonetization  on 13th day of the move. https://t.co/IeXuia3J0X
# ['rt', '@ ashu3page', 'jantar-mantar', 'demonetization']
#
# 180
# RT @rssurjewala: Critical question: Was PayTM informed about #Demonetization edict by PM? It's clearly fishy and requires full disclosure &amp;
# ['rt', '@ rssurjewala', 'critical', 'was paytm', 'demonetization', 'pm', 'full disclosure']
#
# 181
# RT @Punitspeaks: Survey result so far by @PMOIndia on #Demonetization. 5 lakh response in 24 hrs. 90% supports note ban. #MeraDeshBadalRaha
# ['rt', 'punitspeaks', 'survey', 'pmoindia', 'demonetization', 'lakh response', '% supports note ban', 'meradeshbadalraha']
#
# 182
# RT @_Hinduism_: How come those people crying for line in banks are not crying for line ups here in......
#
# #demonetization https://t.co/ixY1
# ['rt', '@ _hinduism_', 'line ups', '... ... # demonetization https']
#
# 183
# RT @ShashiTharoor: . @anandkamal Frankly i don't understand why @narendramodi doesn't address Parlmnt on #Demonetization. It's his duty&amp;wil
# ['rt', 'shashitharoor', '@ anandkamal', 'frankly', '@ narendramodi', "n't address", 'parlmnt', 'demonetization']
#
# 184
# RT @kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti
# ['rt', '@ kanimozhi', 'ts', 'pappu', 'demonetization', 'modi', 'bandwagon ti']
#
# 185
# RT @myvotetoday: Modi's #demonetization received massive public approval. So why is opposition worried about common man and create ruckus i
# ['rt', '@ myvotetoday', 'modi', "'s # demonetization", 'massive public approval', 'common man', 'ruckus i']
#
# 186
# RT @Punitspeaks: Survey result so far by @PMOIndia on #Demonetization. 5 lakh response in 24 hrs. 90% supports note ban. #MeraDeshBadalRaha
# ['rt', 'punitspeaks', 'survey', 'pmoindia', 'demonetization', 'lakh response', '% supports note ban', 'meradeshbadalraha']
#
# 187
# Harvard's Larry Summers calls #Demonetization as poor policy with disproportionate negative impact on poor/trade.
#
# https://t.co/2Tt2SfM0g0
# ['harvard', 'larry summers', 'calls #', 'demonetization', 'poor policy', 'disproportionate negative impact']
#
# 188
# RT @ShashiTharoor: . @anandkamal Frankly i don't understand why @narendramodi doesn't address Parlmnt on #Demonetization. It's his duty&amp;wil
# ['rt', 'shashitharoor', '@ anandkamal', 'frankly', '@ narendramodi', "n't address", 'parlmnt', 'demonetization']
#
# 189
# RT @IndiaFactsOrg: #Demonetization: The Ultimate Weapon against Black economy https://t.co/fWvEuH2De6 via @IndiaFactsOrg
# ['rt', 'indiafactsorg', 'demonetization', 'ultimate weapon', 'black', 'economy https', 'indiafactsorg']
#
# 190
# RT @ShashiTharoor: Joined the line of Opposition MPs demonstrating solidarity on #demonetization &amp;demanding that @PMOIndia address Parliame
# ['rt', 'shashitharoor', 'joined', 'mps', '# demonetization', 'pmoindia', 'parliame']
#
# 191
# Monumental blunder or monumental plunder or both? #demonetization
# ['monumental', '# demonetization']
#
# 192
# RT @rishibagree: And they say #demonetization is failure https://t.co/WnjIUqIhdW
# ['rt', '@ rishibagree', '# demonetization', 'failure https']
#
# 193
# RT @DrGPradhan: 8
#
# This tweet of @minimathur BIBI explains why she is having a prob with #demonetization ..In first part she says she can't
# ['rt', 'drgpradhan', '@ minimathur', 'bibi', '# demonetization ..in', "ca n't"]
#
# 194
# Modi acted against national interest. The way to cashless economy need not be #Demonetization. A badly planned move.
# ['modi', 'national interest', 'cashless economy need', 'demonetization']
#
# 195
# RT @Atheist_Krishna: The effect of #Demonetization !!
# . https://t.co/A8of7zh2f5
# ['rt', 'atheist_krishna', 'demonetization']
#
# 196
# RT @rishibagree: More than 700 Fish Vendors across Kolkata have started using e-wallets.
# Before #demonetization this number was zero .. Thi
# ['rt', '@ rishibagree', 'fish vendors', 'kolkata', '# demonetization', 'zero ..', 'thi']
#
# 197
# RT @rssurjewala: Critical question: Was PayTM informed about #Demonetization edict by PM? It's clearly fishy and requires full disclosure &amp;
# ['rt', '@ rssurjewala', 'critical', 'was paytm', 'demonetization', 'pm', 'full disclosure']
#
# 198
# RT @Punitspeaks: Survey result so far by @PMOIndia on #Demonetization. 5 lakh response in 24 hrs. 90% supports note ban. #MeraDeshBadalRaha
# ['rt', 'punitspeaks', 'survey', 'pmoindia', 'demonetization', 'lakh response', '% supports note ban', 'meradeshbadalraha']
#
# 199
# RT @Hemant_80: Did you vote on #Demonetization on Modi survey app?
# ['rt', 'hemant_80', 'demonetization', 'modi', 'survey app']
#
# 200
# RT @Atheist_Krishna: BEFORE and AFTER Gandhi ji heard they are standing there against #Demonetization
# . https://t.co/9NheK63TPg
# ['rt', 'atheist_krishna', 'before', 'after gandhi', 'demonetization']
#
# 201
# RT @Atheist_Krishna: The effect of #Demonetization !!
# . https://t.co/A8of7zh2f5
# ['rt', 'atheist_krishna', 'demonetization']
#
# 202
# ...
# ['rt', 'drkumarvishwas', 'oscar', 'mr.', 'u+092d', '> <', 'u+093e', '> <', 'u+0935', '> <', 'u+0941', '> <', 'u+0915', '> <', 'u+00a0', '> <', 'u+00bd', '> <', '> <', 'u+00b8', '> <', 'u+00a9', '> <', '> <', 'u+00a0', '> <', 'u+00bd', '> <', '> <', 'u+00b8', '> <', 'u+00a5', '> <', '> <', 'u+00a0', '> <', 'u+00bd', '> <', '> <', 'u+00b8', '> <', 'u+00a2', '> <', '> <', 'u+00a0', '> <', 'u+00bd', '> <', '> <', 'u+00b8', '> <', 'u+00ad', '> # demonetization https']
#
# 433
# #Demonetization will be due from a thousand cuts - each loophole that legalizes the old currency. This is 1 of them https://t.co/smM9g2sP71
# ['demonetization', 'old currency']
#
# 434
# RT @DrGPradhan: 8
#
# This tweet of @minimathur BIBI explains why she is having a prob with #demonetization ..In first part she says she can't
# ['rt', 'drgpradhan', '@ minimathur', 'bibi', '# demonetization ..in', "ca n't"]
#
# 435
# till 2014 it was people Vs corrupt @INCIndia led UPA etc;now after #demonetization it is people Vs tax terrorist Govt of @narendramodi
# ['vs', 'corrupt @', 'incindia', 'upa', '# demonetization', 'vs', 'tax terrorist', 'govt', '@ narendramodi']
#
# 436
# RT @Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards
# ['rt', 'dipankar_cpiml', 'modi', 'demonetization']
#
# 437
# RT @Atheist_Krishna: BEFORE and AFTER Gandhi ji heard they are standing there against #Demonetization
# . https://t.co/9NheK63TPg
# ['rt', 'atheist_krishna', 'before', 'after gandhi', 'demonetization']
#
# 438
# EXCLUSIVE: Inside Paytm, the first 24 hours after #demonetization https://t.co/MGg8yfaEaw via @bi_india
# ['exclusive', 'paytm', '# demonetization https', '@ bi_india']
#
# 439
# RT @pGurus1: #Demonetization move of Modi; Who is supporting it, who is opposing it and why? A complete coverage of all parties - https://t
# ['rt', '@ pgurus1', 'demonetization', 'modi', 'who', 'complete coverage']
#
# 440
# RT @kanimozhi: Ts is exactly what Pappu &amp; opposition has done to themselves by opposing #Demonetization Now none can stop Modi bandwagon ti
# ['rt', '@ kanimozhi', 'ts', 'pappu', 'demonetization', 'modi', 'bandwagon ti']
#
# 441
# RT @Atheist_Krishna: BEFORE and AFTER Gandhi ji heard they are standing there against #Demonetization
# . https://t.co/9NheK63TPg
# ['rt', 'atheist_krishna', 'before', 'after gandhi', 'demonetization']
#
# 442
# RT @MBQasmi: This is a simple survey at my Facebook page. This too shows mood of the nation on #demonetization Modi has asked wrong questio
# ['rt', 'mbqasmi', 'simple survey', 'facebook', 'shows mood', '# demonetization', 'modi', 'wrong questio']
#
# 443
# RT @Atheist_Krishna: BEFORE and AFTER Gandhi ji heard they are standing there against #Demonetization
# . https://t.co/9NheK63TPg
# ['rt', 'atheist_krishna', 'before', 'after gandhi', 'demonetization']
#
# 444
# RT @anechidna: nov 28 - work 1 hr,  stand in queue for 8 hr.  #IAmWithModi  #demonization #tughlakmodi #demonetization
# ['rt', '@ anechidna', 'iamwithmodi', '# demonization # tughlakmodi # demonetization']
#
# 445
# RT @siri_notsiri: Spoke about #demonetization in #India and its impact on #women with @MarcoWerman @pritheworld  https://t.co/EYJfem34nO
# ['rt', '@ siri_notsiri', 'spoke', '# demonetization', 'india', '# women', 'marcowerman', '@ pritheworld https']
#
# 446
# RT @MahikaInfra: Must Vote
#
# After 9days of #demonetization Only 4-5Lakhs cr returned to Bank out of 14.5 Lakhs cr
#
# Kahan gaya 10 Lakhs Cr
# ['rt', 'mahikainfra', 'vote', '# demonetization', '4-5lakhs cr', 'lakhs', 'kahan', 'lakhs cr']
#
# 447
# RT @MahikaInfra: Must Vote
#
# After 9days of #demonetization Only 4-5Lakhs cr returned to Bank out of 14.5 Lakhs cr
#
# Kahan gaya 10 Lakhs Cr
# ['rt', 'mahikainfra', 'vote', '# demonetization', '4-5lakhs cr', 'lakhs', 'kahan', 'lakhs cr']
#
# 448
# Why some bullshits are trying g to be spokesperson of public on #Demonetization.Let them decide.
# ['demonetization.let']
#
# 449
# RT @Punitspeaks: Survey result so far by @PMOIndia on #Demonetization. 5 lakh response in 24 hrs. 90% supports note ban. #MeraDeshBadalRaha
# ['rt', 'punitspeaks', 'survey', 'pmoindia', 'demonetization', 'lakh response', '% supports note ban', 'meradeshbadalraha']
#
# 450
# RT @rajeev_mp: Today again #demonetization debate in Parlmnt stalled due to disruption ! <ed><U+00A0><U+00BD><ed><U+00B9><U+0084> i dont undrstnd why oppstn wants to stall its ow
# ['rt', '@ rajeev_mp', '# demonetization debate', 'parlmnt', '> <', 'u+00a0', '> <', 'u+00bd', '> <', '> <', 'u+00b9', '> <', 'u+0084', '> i dont undrstnd']
#
# 451
# nov 28 - work 1 hr,  stand in queue for 8 hr.  #IAmWithModi  #demonization #tughlakmodi #demonetization
# ['iamwithmodi', '# demonization # tughlakmodi # demonetization']
#
# 452
# RT @DrGPradhan: 8
#
# This tweet of @minimathur BIBI explains why she is having a prob with #demonetization ..In first part she says she can't
# ['rt', 'drgpradhan', '@ minimathur', 'bibi', '# demonetization ..in', "ca n't"]
#
# 453
# RT @RealHistoryPic: Can't say anything about Productivity but Creativity has increased after #Demonetization.(2016) https://t.co/0fMh3UMbVq
# ['rt', 'realhistorypic', 'ca', 'creativity', 'demonetization']
#
# 454
# RT @Atheist_Krishna: BEFORE and AFTER Gandhi ji heard they are standing there against #Demonetization
# . https://t.co/9NheK63TPg
# ['rt', 'atheist_krishna', 'before', 'after gandhi', 'demonetization']
#
# 455
# @chaks1969 @mvmeet Well educated Keralites &amp; Bengali's will support Bandh not coz #Demonetization they only know to react not respond
# ['@ chaks1969 @ mvmeet', 'well', 'keralites', 'bengali', 'bandh', 'coz #', 'demonetization']
#
# 456
# RT @MahikaInfra: Must Vote
#
# After 9days of #demonetization Only 4-5Lakhs cr returned to Bank out of 14.5 Lakhs cr
#
# Kahan gaya 10 Lakhs Cr
# ['rt', 'mahikainfra', 'vote', '# demonetization', '4-5lakhs cr', 'lakhs', 'kahan', 'lakhs cr']
#
# 457
# RT @BrainandMoney: The effect of #Demonetization !!
# @ravishndtv @ShekharGupta @hvgoenka @mrsfunnybones @GabbbarSingh @Iamanirudhsethi https
# ['rt', 'brainandmoney', 'demonetization', '@ ravishndtv @', 'shekhargupta', '@ hvgoenka @ mrsfunnybones @', 'gabbbarsingh', 'iamanirudhsethi']
#
# 458
# RT @Hemant_80: Did you vote on #Demonetization on Modi survey app?
# ['rt', 'hemant_80', 'demonetization', 'modi', 'survey app']
#
# 459
# RT @DrGPradhan: 8
#
# This tweet of @minimathur BIBI explains why she is having a prob with #demonetization ..In first part she says she can't
# ['rt', 'drgpradhan', '@ minimathur', 'bibi', '# demonetization ..in', "ca n't"]
#
# 460
# RT @Hemant_80: Did you vote on #Demonetization on Modi survey app?
# ['rt', 'hemant_80', 'demonetization', 'modi', 'survey app']
#
# 461
# RT @ShashiTharoor: Joined the line of Opposition MPs demonstrating solidarity on #demonetization &amp;demanding that @PMOIndia address Parliame
# ['rt', 'shashitharoor', 'joined', 'mps', '# demonetization', 'pmoindia', 'parliame']
#
# 462
# RT @ModiBharosa: Huge support for PM @narendramodi s #demonetization Move Across the Nation
# 80-86% people back demonetization: C-voter su
# ['rt', 'modibharosa', 'huge', 'pm', '@ narendramodi \x92s # demonetization', 'move across', 'nation', '% people', 'c-voter']
#
# 463
# RT @ShashiTharoor: Joined the line of Opposition MPs demonstrating solidarity on #demonetization &amp;demanding that @PMOIndia address Parliame
# ['rt', 'shashitharoor', 'joined', 'mps', '# demonetization', 'pmoindia', 'parliame']
#
# 464
# RT @DrGPradhan: 8
#
# This tweet of @minimathur BIBI explains why she is having a prob with #demonetization ..In first part she says she can't
# ['rt', 'drgpradhan', '@ minimathur', 'bibi', '# demonetization ..in', "ca n't"]
#
# 465
# How to convert all your black money into white following the #DeMonetization: How to https://t.co/kHiIqcCJqO
# ['black money', 'demonetization']
#
# 466
# RT @harshkkapoor: #DeMonetization survey results after 24 hours
# 5Lacs opinions
# Amazing response&amp; Commitment in fight against Blackmoney
# @na
# ['rt', '@ harshkkapoor', 'demonetization', 'survey results', 'hours 5lacs opinions', 'amazing', 'commitment', 'blackmoney', '@ na']
#
# 467
# RT @DrGPradhan: 8
#
# This tweet of @minimathur BIBI explains why she is having a prob with #demonetization ..In first part she says she can't
# ['rt', 'drgpradhan', '@ minimathur', 'bibi', '# demonetization ..in', "ca n't"]
#
# 468
# Wed 23 Nov 2016 Communist Party of #India files petition with Supreme Court #challenging government's controversial #demonetization decision
# ['wed', 'nov', 'communist party', 'india', 'files petition', 'supreme court #', "challenging government 's", 'controversial # demonetization decision']
#
# 469
# Any move against #demonetization should b compared 2 treason! This move may hv created little trouble but it's gonna save India
# #netascashin
# ['# demonetization', "'s gon na", 'india', '# netascashin']
#
# 470
# RT @Punitspeaks: Survey result so far by @PMOIndia on #Demonetization. 5 lakh response in 24 hrs. 90% supports note ban. #MeraDeshBadalRaha
# ['rt', 'punitspeaks', 'survey', 'pmoindia', 'demonetization', 'lakh response', '% supports note ban', 'meradeshbadalraha']
#
# 471
# then the result will be #Demonetization regrets. Will rural economy turn #cashless. Remains to be seen.
# ['demonetization', 'will', 'rural economy', '# cashless', 'remains']
#
# 472
# RT @BaradaDs: Oppositions demand strike #<U+0906><U+092A>_<U+092A><U+093E><U+0917><U+0932>_<U+0939><U+0948><U+0902>
# #DeMonetization
# ['rt', 'baradads', 'oppositions', 'demand strike # <', 'u+0906', '> <', 'u+092a', '> _ <', 'u+092a', '> <', 'u+093e', '> <', 'u+0917', '> <', 'u+0932', '> _ <', 'u+0939', '> <', 'u+0948', '> <', 'u+0902', '> #', 'demonetization']
#
# 473
# RT @DrGPradhan: 8
#
# This tweet of @minimathur BIBI explains why she is having a prob with #demonetization ..In first part she says she can't
# ['rt', 'drgpradhan', '@ minimathur', 'bibi', '# demonetization ..in', "ca n't"]
#
# 474
# RT @Atheist_Krishna: The effect of #Demonetization !!
# . https://t.co/A8of7zh2f5
# ['rt', 'atheist_krishna', 'demonetization']
#
# 475
# RT @Hemant_80: Did you vote on #Demonetization on Modi survey app?
# ['rt', 'hemant_80', 'demonetization', 'modi', 'survey app']
#
# 476
# #Demonetization #India #EconomicsBehind
# Economics behind demonetization of Rs 1000 &amp; 500 notes.
# https://t.co/XK1TlhmT8c
# ['demonetization', 'india', 'economicsbehind economics', 'rs']
#
# 477
# RT @Punitspeaks: Survey result so far by @PMOIndia on #Demonetization. 5 lakh response in 24 hrs. 90% supports note ban. #MeraDeshBadalRaha
# ['rt', 'punitspeaks', 'survey', 'pmoindia', 'demonetization', 'lakh response', '% supports note ban', 'meradeshbadalraha']
#
# 478
# RT @harshkkapoor: #DeMonetization survey results after 24 hours
# 5Lacs opinions
# Amazing response&amp; Commitment in fight against Blackmoney
# @na
# ['rt', '@ harshkkapoor', 'demonetization', 'survey results', 'hours 5lacs opinions', 'amazing', 'commitment', 'blackmoney', '@ na']
#
# 479
# RT @Atheist_Krishna: BEFORE and AFTER Gandhi ji heard they are standing there against #Demonetization
# . https://t.co/9NheK63TPg
# ['rt', 'atheist_krishna', 'before', 'after gandhi', 'demonetization']
#
# 480
# RT @Punitspeaks: Survey result so far by @PMOIndia on #Demonetization. 5 lakh response in 24 hrs. 90% supports note ban. #MeraDeshBadalRaha
# ['rt', 'punitspeaks', 'survey', 'pmoindia', 'demonetization', 'lakh response', '% supports note ban', 'meradeshbadalraha']
#
# 481
# RT @Dipankar_cpiml: The Modi app on #DeMonetization proves once again that the govt is totally indifferent to the mounting misery and hards
# ['rt', 'dipankar_cpiml', 'modi', 'demonetization']
#
# 482
# RT @Hemant_80: Did you vote on #Demonetization on Modi survey app?
# ['rt', 'hemant_80', 'demonetization', 'modi', 'survey app']
#
# 483
# RT @Atheist_Krishna: BEFORE and AFTER Gandhi ji heard they are standing there against #Demonetization
# . https://t.co/9NheK63TPg
# ['rt', 'atheist_krishna', 'before', 'after gandhi', 'demonetization']
#
# 484
# Oppositions demand strike #<U+0906><U+092A>_<U+092A><U+093E><U+0917><U+0932>_<U+0939><U+0948><U+0902>
# #DeMonetization
# ['oppositions', 'demand strike # <', 'u+0906', '> <', 'u+092a', '> _ <', 'u+092a', '> <', 'u+093e', '> <', 'u+0917', '> <', 'u+0932', '> _ <', 'u+0939', '> <', 'u+0948', '> <', 'u+0902', '> #', 'demonetization']
#
# 485
# RT @Punitspeaks: Survey result so far by @PMOIndia on #Demonetization. 5 lakh response in 24 hrs. 90% supports note ban. #MeraDeshBadalRaha
# ['rt', 'punitspeaks', 'survey', 'pmoindia', 'demonetization', 'lakh response', '% supports note ban', 'meradeshbadalraha']
#
# 486
# RT @DrGPradhan: 8
#
# This tweet of @minimathur BIBI explains why she is having a prob with #demonetization ..In first part she says she can't
# ['rt', 'drgpradhan', '@ minimathur', 'bibi', '# demonetization ..in', "ca n't"]
#
# 487
# RT @gauravcsawant: Rs 40 lakh looted from a bank in Kishtwar in J&amp;K. Third such incident since #demonetization. That's how terrorists have
# ['rt', '@ gauravcsawant', 'rs', 'kishtwar', 'k.', 'such incident', '# demonetization']
#
# 488
# RT @Punitspeaks: Survey result so far by @PMOIndia on #Demonetization. 5 lakh response in 24 hrs. 90% supports note ban. #MeraDeshBadalRaha
# ['rt', 'punitspeaks', 'survey', 'pmoindia', 'demonetization', 'lakh response', '% supports note ban', 'meradeshbadalraha']
#
# 489
# When u see ppl like Mamta &amp; Mayawati raising question abt #demonetization , thn anyone will be agree that it's good move by Modi #NoteBandi
# ['mamta', 'mayawati', 'question abt # demonetization', 'modi', 'notebandi']
#
# 490
# RT @ShashiTharoor: Joined the line of Opposition MPs demonstrating solidarity on #demonetization &amp;demanding that @PMOIndia address Parliame
# ['rt', 'shashitharoor', 'joined', 'mps', '# demonetization', 'pmoindia', 'parliame']
#
# 491
# RT @Bollywood_Stuff: #RakhiSawant Support #demonetization of #Currency By #PMModi
#
# VIDEO<U+279C>https://t.co/n7kvc1wsCy
#
# #Rs500andRs1000 #bollywo
# ['rt', 'bollywood_stuff', 'rakhisawant support', '# demonetization', 'currency', 'pmmodi video', 'u+279c', '> https', '//t.co/n7kvc1wscy #', 'rs500andrs1000', '# bollywo']
#
# 492
# Spoke about #demonetization in #India and its impact on #women with @MarcoWerman @pritheworld  https://t.co/EYJfem34nO
# ['spoke', '# demonetization', 'india', '# women', 'marcowerman', '@ pritheworld https']
#
# 493
# RT @SreeIyer1: #Demonetization The time has come to put MUDRA into action, writes Prof. R Vaidyanathan - https://t.co/7SESPjFTD4 @Swamy39 @
# ['rt', 'sreeiyer1', 'demonetization', 'mudra', 'prof. r vaidyanathan', '//t.co/7sespjftd4 @', 'swamy39']
#
# 494
# RT @Punitspeaks: Survey result so far by @PMOIndia on #Demonetization. 5 lakh response in 24 hrs. 90% supports note ban. #MeraDeshBadalRaha
# ['rt', 'punitspeaks', 'survey', 'pmoindia', 'demonetization', 'lakh response', '% supports note ban', 'meradeshbadalraha']
#
# 495
# 5lakh from 24.7mil followers of @narendramodi is ~2% only &amp; abt 0.04% only frm 1.2bil India population #demonetization @ndtv #NOT90%ofIndia
# ['24.7mil followers', '@ narendramodi', '~2 %', 'frm 1.2bil', 'india', 'population # demonetization @ ndtv #', 'not90', '% ofindia']
#
# 496
# RT @DrGPradhan: 8
#
# This tweet of @minimathur BIBI explains why she is having a prob with #demonetization ..In first part she says she can't
# ['rt', 'drgpradhan', '@ minimathur', 'bibi', '# demonetization ..in', "ca n't"]
#
# 497
# RT @DrGPradhan: 8
#
# This tweet of @minimathur BIBI explains why she is having a prob with #demonetization ..In first part she says she can't
# ['rt', 'drgpradhan', '@ minimathur', 'bibi', '# demonetization ..in', "ca n't"]
#
# 498
# Only 5 Lakhs Responses' on #Demonetization?? #Modi ji has more than 20.4 millions follower's on #Twitter &amp; approx... https://t.co/WdoITzJ7n2
# ['lakhs responses', 'demonetization', 'modi', "millions follower 's", 'twitter', 'approx ... https']
#
# 499
# RT @DrGPradhan: 8
#
# This tweet of @minimathur BIBI explains why she is having a prob with #demonetization ..In first part she says she can't
# ['rt', 'drgpradhan', '@ minimathur', 'bibi', '# demonetization ..in', "ca n't"]
